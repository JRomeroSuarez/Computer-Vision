# %% [markdown]
# # Computer Vision - Laboratory

# %% [markdown]
# ## Practicum 1: Basics on Image Processing and Manipulation
#
# The main topics are:
# 1. Image loading, saving and creation
# 2. Color manipulation
#
# In order to complete this practicum, we will work with the following concepts: image creation, data types, image manipulation.

# %% [markdown]
# ### Packages loading
#
# First we need to import the required Python packages for basic image manipulation.
#
# Run the following code:

# %%
import numpy as np # useful for manipulating matrices
from skimage import io # useful for image loading and saving
from matplotlib import pyplot as plt # useful for plotting images on iPython or Jupyter Notebooks

# %% [markdown]
# Note that commands starting with the percentage sign (`%`) are special internal commands to ipython (as opposed to Python code to be run). In the case below, we set the matplotlib environment to display images results inline (i.e. the images will be shown **inside the
# notebook**):

# %%
# %matplotlib inline

# %% [markdown]
# ### 1.1 Image creation

# %% [markdown]
# Remember that [Numpy](https://docs.scipy.org/doc/numpy-1.13.0/reference/) allows us to define images of different kinds treating them as matrices.
#
# The most common examples are:
#
# * Binary: with values of 0 or 1, interpreted as black or white, respectively.
# * Grayscale: with possible data types uint8, uint16, double, whose pixel values define their intensity.
# * RGB Image: color images consisting of 3 matrices (usually called 'channels'), which contain intensity values for each color separately R (red), G (green) and B (blue).

# %% [markdown]
# a) Create and display a grayscale image that has 150 rows and 200 columns where each value should be of type unsigned integer with 8 bits.

# %%
#Your solution
size = (150, 200) #Size of the image(Row, Columns)

dtype = np.uint8 #Type of the values

img = np.ndarray(size, dtype) #Grid with the size and type of values
cmap ="gray" #Colormap as gray

#Print the image.
plt.imshow(img, cmap)
plt.show()

# %% [markdown]
# How many values can each pixel have in this case?

# %% [markdown]
# ### Solution
# This allows us to represent 2^8 = 256 values in each pixel.

# %% [markdown]
# b) Change the color of the pixels of the image in such a way that the left half is black (0) and the right half is white (255).
#
# Visualize the image and print the values of its first row.

# %%
#Values of the height and width
height = img.shape[0]
width = img.shape[1]


img[:,:int(width/2)] = 0 #Paint from pixel 0 to middle width
img[:, int(width/2):] = 255 #Paint from middle width to last pixel


cmap ="gray" #Colormap as gray

#Print the image.
plt.imshow(img, cmap)
plt.show()

# %% [markdown]
# ### 1.2 Image saving and loading
#
# a) Use the IO image package to save the image previously created:

# %%
#Saving the image
io.imsave('images/blackWhite.jpg',img)

# %% [markdown]
# b) Load the saved image and visualize it:

# %%
#Load the image
load = io.imread('images/blackWhite.jpg')

cmap ="gray" #Colormap as gray

#Print the image.
plt.imshow(img, cmap)
plt.show()

# %% [markdown]
# ### 1.3 Color image manipulation
#
# a) Load and show the image `lenna.jpg`, and check its dimensions.
#
# **Note:** Pictures may appear in the figure with pseudocolors. Use (imread,im,cmap='rgb') to display them in RGB color and (imread,im,cmap='gray') to display them in grayscale. For more information, check the color maps available in the documentation.

# %%
#Load the image
lenna = io.imread('images/lenna.jpg')

#Print the image.
plt.imshow(lenna)
plt.show()

print("Dimensions" + str(lenna.shape))
# Out:
# Dimensions(225, 400, 3)

# %% [markdown]
# b) Convert the previous image to grayscale, visualize and save it. Moreover, show both images (RGB & greyscale) details such as shape, dtype, max and min values.

# %%
from skimage.color import rgb2gray

#Read the image as gray
lenna_gray = rgb2gray(lenna)

cmap = 'gray'
#Print the image.
plt.imshow(lenna_gray,cmap)
plt.show()

print("Shape: " + str(lenna_gray.shape))
print("dtype: " + str(lenna_gray.dtype))
print("Max values: " + str(lenna_gray.max()))
print("Min values: " + str(lenna_gray.min()))


#Save image
io.imsave('images/lenna_blackWhite.jpg',lenna_gray)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Shape: (225, 400)
# dtype: float64
# Max values: 0.9869937254901961
# Min values: 0.0014137254901960784

# %%
fig=plt.figure(figsize=(15,15))
fig.add_subplot(1,3,1)
plt.imshow(lenna, cmap='gray')
plt.title('lenna')
plt.xticks([])
plt.yticks([])
print("Original")
print("Shape: " + str(lenna.shape))
print("dtype: " + str(lenna.dtype))
print("Max values: " + str(lenna.max()))
print("Min values: " + str(lenna.min()))
print("\n")


fig.add_subplot(1,3,2)
plt.imshow(lenna_gray, cmap='gray')
plt.title('lenna_gray')
plt.xticks([])
plt.yticks([])
print("Gray")
print("Shape: " + str(lenna_gray.shape))
print("dtype: " + str(lenna_gray.dtype))
print("Max values: " + str(lenna_gray.max()))
print("Min values: " + str(lenna_gray.min()))
# Out:
# Original
# Shape: (225, 400, 3)
# dtype: uint8
# Max values: 255
# Min values: 0
#
#
# Gray
# Shape: (225, 400)
# dtype: float64
# Max values: 0.9869937254901961
# Min values: 0.0014137254901960784

# %% [markdown]
# c) Convert the lena image into a boolean image, by applying a binarization to the grayscale image. This should be done by setting to 0 all values equal or below 100 and to 1 otherwise. Check the range of the values of the image, and print the 10th row.

# %%
lenna_binarization = io.imread('images/lenna.jpg')
#Mean of the channels
lenna_binarization =lenna_binarization.mean(2)
plt.imshow(lenna_binarization,'gray')
#Binarization of the image
lenna_binarization = lenna_binarization > 100

#Show the binarized image and the 10th row
plt.imshow(lenna_binarization,'gray')
plt.show()
print("10th row: " + str(lenna_binarization[9]))
# Out:
# 10th row: [False False False False False False False False False False False False
#  False False False False False  True  True  True  True  True  True False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False  True False False
#  False False False False False False False  True False False False False
#  False  True False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True False False False False False
#  False False False False False False False  True False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True False False False False
#  False False False False False False False False False False False False
#  False False False False]

# %% [markdown]
# d) Visualize in the same figure three images: (1) the original image, (2) the graylevel image, and (3) the binarized image. Set the corresponding titles of the images.

# %%
#Showing all the images using a subplot of 3 columns
fig=plt.figure(figsize=(15,15))
fig.add_subplot(1,3,1)
plt.imshow(lenna, cmap='gray')
plt.title('lenna')

fig.add_subplot(1,3,2)
plt.imshow(lenna_gray, cmap='gray')
plt.title('lenna_gray')


fig.add_subplot(1,3,3)
plt.imshow(lenna_binarization, cmap='gray')
plt.title('lenna_binarization')

plt.show()

# %% [markdown]
# ### 1.4 Images manipulation
#
# a) Add a black frame to Lenna's image. It should have a width of 1/10th of the height of the original image. We recommend to create a bigger black image to later embed the original image in the central part.

# %%
#Sizes of the image
img_height = lenna.shape[0]
img_width = lenna.shape[1]

#Type of the values
dtype = np.uint8 

#Margin of the image
margin = int(img_height *.1)

#Black image with the new margin
canvas = np.zeros((img_height+2*margin, img_width+2*margin,3),dtype)

#Embeding the original image with the black image
lenna_frame = canvas.copy()
lenna_frame[margin:canvas.shape[0] - margin, margin:canvas.shape[1] - margin] = lenna

plt.imshow(lenna_frame)
plt.show()
print("Dimensions:",canvas.shape)
# Out:
# Dimensions: (269, 444, 3)

# %% [markdown]
# b) Change the mask of the framed image to red. Visualize the three images with their respective titles.

# %%
#Dimensions of the image
img_height = lenna.shape[0]
img_width = lenna.shape[1]
dtype = 'uint8' #Type of the values
margin = int(img_height *.1)

#Red color for paint the frame
red_color = np.array([255,0,0])


#Create the red frame
red_frame = np.full([img_height+2*margin, img_width+2*margin,3],red_color,dtype)

#Embed image in the middle of the black frame
lenna_redFrame = red_frame
lenna_redFrame[margin:canvas.shape[0] - margin, margin:canvas.shape[1] - margin] = lenna


plt.imshow(lenna_redFrame)
plt.show()

# %%
fig=plt.figure(figsize=(15,15))
fig.add_subplot(1,3,1)
plt.imshow(lenna, cmap='gray')
plt.title('Lenna Original')
plt.xticks([])
plt.yticks([])

fig.add_subplot(1,3,2)
plt.imshow(lenna_frame, cmap='gray')
plt.title('Lenna Black Frame')
plt.xticks([])
plt.yticks([])

fig.add_subplot(1,3,3)
plt.imshow(lenna_redFrame, cmap='gray')
plt.title('Lenna Red Frame')
plt.xticks([])
plt.yticks([])

plt.show()

# %% [markdown]
# ### 1.5 Contrast enhancement
#
# a) Open the image `car_lowContrast.jpg` and visualize it without graylevel enhancement. To this purpose, check which are the minimal and maximal values and how to use the command imshow without contrast enhancement.
#
# Note: When running the function `imshow()` the image is authomatically enhanced. Use the `vmin` and `vmax` parameters in order to deactivate the enhancement applied by default.

# %%
#Read the image
car_LW = io.imread('images/car_lowContrast.jpg')

#Show the image using the vmin and vmax values to show the image without contrast enchacement
plt.imshow(car_LW, vmin = 0, vmax = 255)
plt.show()

print("Max values: " + str(car_LW.max()))
print("Min values: " + str(car_LW.min()))
# Out:
# Max values: 193
# Min values: 63

# %% [markdown]
# b) Create an image called `dark_image` using the  values from the original one, so that the minimal value of the new image is 0. Check the minimal and maximal values of the new image, and compare them with the previous one.

# %%
#Decreasing the minimal value substracting
dark_image = car_LW - car_LW.min()

plt.imshow(dark_image, vmin = 0, vmax = 255)
plt.show()

print("Max values: " + str(dark_image.max()))
print("Min values: " + str(dark_image.min()))
# Out:
# Max values: 130
# Min values: 0

# %% [markdown]
# c) Create a new image called `bright_im` from the original one, so that the maximal value of the new image is 255. Check the minimal and maximal values of the new image, and compare them with the previous one.

# %%
#Maximal value adding the difference until 255
bright_im = car_LW + (255 - car_LW.max())

plt.imshow(bright_im, vmin = 0, vmax = 255)
plt.show()

print("Max values: " + str(bright_im.max()))
print("Min values: " + str(bright_im.min()))
# Out:
# Max values: 255
# Min values: 125

# %% [markdown]
# d) Apply contrast enhancement to the original image. There are two ways for it: (1) by direct manipulation, and (2) through scikit-image command. Check the minimal and maximal values of the enhanced image, and compare them with the previous one.
#
# Implement the contrast enhancement using the two different available methods.

# %%
#1st Method: Direct Manipulation
plt.imshow(car_LW, vmin = car_LW.min(), vmax = car_LW.max())
plt.show()

print("Max values: " + str(car_LW.max()))
print("Min values: " + str(car_LW.min()))
# Out:
# Max values: 193
# Min values: 63

# %%
#2nd Method: through scikit-image command
from skimage import exposure
car_LW2 = exposure.equalize_adapthist(car_LW)

plt.imshow(car_LW2)
plt.show()

print("Max values: " + str(car_LW.max()))
print("Min values: " + str(car_LW.min()))
# Out:
# Max values: 193
# Min values: 63

# %% [markdown]
# e) Visualize the 5 images in the same figure, each one with its corresponding title.

# %%
fig1=plt.figure(figsize=(10,10))

fig1.add_subplot(1,2,1)
plt.imshow(car_LW, vmin = 0, vmax = 255)
plt.title('without graylevel enhancement')

fig1.add_subplot(1,2,2)
plt.imshow(dark_image, vmin = 0, vmax = 255)
plt.title('obscured image')

fig=plt.figure(figsize=(10,10))

fig.add_subplot(2,3,1)
plt.imshow(bright_im, vmin = 0, vmax = 255)
plt.title('brighted image')

fig.add_subplot(2,3,2)
plt.imshow(car_LW, vmin = car_LW.min(), vmax = car_LW.max())
plt.title('direct contrast enchament')

fig.add_subplot(2,3,3)
plt.imshow(car_LW2)
plt.title('scikit contrast enchament')


plt.show()

# %% [markdown]
# ### 1.6 Masks and logical image manipulation
#
# Read the image `circles.bmp` (see figure top) and define 3 images in such a way that each one contains only 1 ball (see figure bottom). Visualize the 3 images in the same figure, each one with its corresponding title.
#
# <img src="images_notebook/ex16.png">
#
# **Note:** Be careful when applying `imshow` since it automatically increases the contrast of the image (putting minimum values to 0 and maximal to 1).
#
# **Note:** Be careful when applying type conversion. Check the ranges of the image values.

# %%
from skimage.color import rgb2gray
#Load image
circles = io.imread('images/circles.bmp')

#The circles were rgb and convert to grayscale
circles_gray = rgb2gray(circles)

#We take each color 
color = np.unique(circles_gray)

#Copy the image to work each positin
left_circle = circles_gray.copy()
central_circle = circles_gray.copy()
right_circle = circles_gray.copy()

circles = [left_circle,central_circle,right_circle]

for i in range(len(color)-1):
    circles[i][circles_gray != color[i]] = 1
    
    
fig=plt.figure(figsize=(15,15))
fig.add_subplot(1,3,1)
plt.imshow(left_circle, cmap='gray',vmin =0 , vmax = 1)
plt.title('left_circle')


fig.add_subplot(1,3,2)
plt.imshow(central_circle, cmap='gray',vmin = 0, vmax = 1)
plt.title('central_circle')


fig.add_subplot(1,3,3)
plt.imshow(right_circle, cmap='gray',vmin = 0, vmax = 1)
plt.title('right_circle')


plt.show()

# %% [markdown]
# ### 1.7 Color manipulation
#
# a) Create and visualize the three images shown in the following figure:
# <img src="./images_notebook/ex17a.png">

# %%
#Size of the images
size = (50,50,3)

#Type of the values 
dtype = np.uint8

#Creating the figures with the size and dtype
img1 = np.zeros(size, dtype)
img2 = np.zeros(size, dtype)
img3 = np.zeros(size, dtype)

#Create the figures 
img1[:,img1.shape[1]//2:] = 255
img2[img2.shape[1]//2:,:] = 255
img3[:img3.shape[0]//2,:img3.shape[1]//2] = 255

#Print all the images 
fig=plt.figure(figsize=(15,15))
fig.add_subplot(1,3,1)
plt.imshow(img1, cmap='gray')
plt.title('img1')

fig.add_subplot(1,3,2)
plt.imshow(img2, cmap='gray')
plt.title('img2')

fig.add_subplot(1,3,3)
plt.imshow(img3, cmap='gray')
plt.title('img3')

plt.show()

# %% [markdown]
# b) Using these three images, construct the following color image:
# <img src='./images_notebook/ex17b.png'>

# %%
#We search the white of the image1 and paint red(right)
img1[img1[...,0]== 255] = [255,0,0]
#We search the white of the image2 and paint green(downside), and we got yellow too
img2[img2[...,0]== 255] = [0,255,0]
#We search the white of the image3 and paint green(left upside)
img3[img3[...,0]== 255] = [0,0,255]

#We join all the matrices into one
img = img1 + img2 + img3

plt.imshow(img)
plt.show()

# %% [markdown]
# c) Read and visualize the image `sillas.jpg` (see figure top). Extract its three channels and visualize them in the same figure with their respective titles (see the figure bottom).
# <img src="images_notebook/ex17c.png">
#
# <img src="images_notebook/ex17c2.png">

# %%
sillas = io.imread('images/sillas.jpg')

red_chair = sillas.copy()[:,:,0] #Extract red color
green_chair = sillas.copy()[:,:,1] #Extract green color
blue_chair = sillas.copy()[:,:,2] #Extract blue color

#Showing the original image
fig1=plt.figure(figsize=(15,15))
fig1.add_subplot(1,3,1)
plt.imshow(sillas, cmap='gray')
plt.title('Original image')

#Create new sublplot
fig=plt.figure(figsize=(15,15))

#Showing the red channel
fig.add_subplot(2,3,1)
plt.imshow(red_chair, cmap='gray')
plt.title('Red channel')

#Showing the green channel
fig.add_subplot(2,3,2)
plt.imshow(green_chair, cmap='gray')
plt.title('Green channel')

#Showing the blue channel
fig.add_subplot(2,3,3)
plt.imshow(green_chair, cmap='gray')
plt.title('Blue channel')

plt.show()

# %% [markdown]
# d) Construct and visualize a new image in which the red color of the chairs is changed to blue (see figure).
# <img src="images_notebook/ex17c3.png">

# %%
#Copy the image to change the color channels
blue_chairs = sillas.copy()

#Swap blue and red colors
blue_chairs[:,:,0] = sillas[:,:,2]
blue_chairs[:,:,2] = sillas[:,:,0]

#Display the image
fig1=plt.figure(figsize=(15,15))
fig1.add_subplot(1,3,1)
plt.imshow(blue_chairs, cmap='gray')
plt.title('Blue image')
plt.show()

# %% [markdown]
# e) Given the images `coat.png` and `model.png` (first two images on the figure below), implement the necessary code to construct the image of the model with the coat (third image). Next find in internet an image with a texture and apply it to obtain an image of the jacket with the found texture (fourth image is only an example).
#
# <img src="images_notebook/ex17d.png">
#
# **Note:** when applying resize, rotate, etc. keep track how the image type and values range change. When necessary, apply type conversion using img_as_float, img_as_uint, img_as_ubyte.

# %%
#Read the coat and model images
coat = io.imread('images/coat.png')
model = io.imread('images/model.png')

#Sizes of the images
height = model.shape[0]
width = model.shape[1]

for i in range(height):
    for j in range(width):
        #We look at when it stops being black, that is, it is coat
        if(coat[i][j][0] != 0) and(coat[i][j][1] != 0) and (coat[i][j][2] != 0):
                model[i][j] = coat[i][j] #We change the pixels of the model for the coat
            
plt.imshow(model, cmap='gray')
# Out:
# [  0   0   0 255]
# Text(0.5, 1.0, 'img1')

# %%
#Read all the images
coat = io.imread('images/coat.png')
model = io.imread('images/model.png')
texture = io.imread('images/texture.png')
texture2 = io.imread('images/texture2.png')

height1, width1, dimension = texture.shape

height2, width2, dimension = texture2.shape


height = model.shape[0]
width = model.shape[1]
for i in range(height):
    for j in range(width):
        #We look at when it stops being black, that is, it is coat
        if(coat[i][j][0] != 0) and(coat[i][j][1] != 0) and (coat[i][j][2] != 0):
            for channel in range(3): #Iterate trough the 3 channels
                model[i][j][channel] = texture2[i][j][channel] #We change the pixels of the model for the coat
            
plt.imshow(model, cmap='gray')
# Out:
# 183
# 275
# 1188
# 915

# %% [markdown]
# ## Delivery
#
# Compressed file **P1_Student1_Student2.zip** that includes:
# - The notebook P1_Student1_Student2.ipynb completed with the solutions to the exercises and their corresponding comments.
# - The images used that are not provided in P1.zip.
#
# **Deadline (Campus Virtual): October 13, 11:00 p.m.**
